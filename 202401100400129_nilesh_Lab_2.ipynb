# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error as mse
import seaborn as sns

# %%
def sigmoid(z):
    return 1 /(1+ np.exp(-z))

# %%
def derivative_sigmoid(z):
    s=sigmoid(z)
    return s*(1-s)

# %%
X = [1, 2, 3, 4, 5]
y = []

for i in X:
    y.append(i * 2)

# %%
X = np.array(X)
y = np.array(y)

# %%
hd_w = np.random.rand(1)[0]
hd_b = np.random.rand(1)[0]
op_w = np.random.rand(1)[0]
op_b = np.random.rand(1)[0]

# %%
losses=[]
epoch=60
learning_rate=0.03

# %%
for i in range(epoch):

    z1 = X * hd_w + hd_b
    a1 = sigmoid(z1)

    z2 = op_w * a1 + op_b
    y_pred = sigmoid(z2)


    loss = np.mean((y - y_pred) ** 2)
    print(f"Epoch {i+1}, Loss: {loss}")
    losses.append(loss)


    error = y_pred - y

    err_o = error * derivative_sigmoid(z2)

    hid_err = err_o * op_w
    err_hid = hid_err * derivative_sigmoid(z1)


    op_w = op_w - learning_rate * np.mean(err_o * a1)
    op_b = op_b - learning_rate * np.mean(err_o)

    hd_w = hd_w - learning_rate * np.mean(err_hid * X)
    hd_b = hd_b - learning_rate * np.mean(err_hid)
# Out:
# Epoch 1, Loss: 35.46457807181845
# Epoch 2, Loss: 35.35544687488875
# Epoch 3, Loss: 35.25285777397539
# Epoch 4, Loss: 35.15656430945254
# Epoch 5, Loss: 35.06626286002516
# Epoch 6, Loss: 34.98161690411315
# Epoch 7, Loss: 34.90227556207459
# Epoch 8, Loss: 34.82788701762742
# Epoch 9, Loss: 34.758107732796844
# Epoch 10, Loss: 34.69260840563804
# Epoch 11, Loss: 34.6310775149938
# Epoch 12, Loss: 34.57322314147068
# Epoch 13, Loss: 34.5187735972504
# Epoch 14, Loss: 34.46747726095466
# Epoch 15, Loss: 34.41910190400801
# Epoch 16, Loss: 34.37343371082052
# Epoch 17, Loss: 34.33027613272576
# Epoch 18, Loss: 34.28944867041224
# Epoch 19, Loss: 34.25078564741441
# Epoch 20, Loss: 34.21413501465916
# Epoch 21, Loss: 34.17935721043494
# Epoch 22, Loss: 34.1463240894724
# Epoch 23, Loss: 34.11491792764042
# Epoch 24, Loss: 34.085030504018754
# Epoch 25, Loss: 34.05656225906248
# Epoch 26, Loss: 34.02942152569286
# Epoch 27, Loss: 34.003523829064974
# Epoch 28, Loss: 33.978791250213085
# Epoch 29, Loss: 33.955151848580826
# Epoch 30, Loss: 33.93253913847889
# Epoch 31, Loss: 33.91089161469192
# Epoch 32, Loss: 33.89015232272072
# Epoch 33, Loss: 33.87026846945473
# Epoch 34, Loss: 33.85119107039706
# Epoch 35, Loss: 33.83287462989332
# Epoch 36, Loss: 33.81527685113408
# Epoch 37, Loss: 33.798358373002884
# Epoch 38, Loss: 33.782082531124516
# Epoch 39, Loss: 33.766415140728235
# Epoch 40, Loss: 33.751324299179394
# Epoch 41, Loss: 33.736780206249776
# Epoch 42, Loss: 33.72275500039301
# Epoch 43, Loss: 33.709222609469094
# Epoch 44, Loss: 33.69615861452062
# Epoch 45, Loss: 33.68354012534713
# Epoch 46, Loss: 33.671345666751556
# Epoch 47, Loss: 33.65955507444808
# Epoch 48, Loss: 33.648149399723046
# Epoch 49, Loss: 33.63711082203287
# Epoch 50, Loss: 33.62642256880473
# Epoch 51, Loss: 33.61606884177962
# Epoch 52, Loss: 33.60603474930299
# Epoch 53, Loss: 33.59630624402675
# Epoch 54, Loss: 33.586870065539735
# Epoch 55, Loss: 33.57771368748998
# Epoch 56, Loss: 33.568825268805135
# Epoch 57, Loss: 33.560193608654636
# Epoch 58, Loss: 33.55180810483172
# Epoch 59, Loss: 33.54365871526322
# Epoch 60, Loss: 33.53573592238303

# %%
print("Final Prediction: ",y_pred)
# Out:
# Final Prediction:  [0.9356559  0.94146976 0.94536343 0.94792099 0.94958151]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(losses, color='forestgreen', linewidth=2)
plt.title("Model Training Loss")
plt.xlabel("Steps")
plt.ylabel("MSE Loss")
plt.show()

# %%
print("Predicted Output:")
print(np.round(y_pred, 3))
# Out:
# Predicted Output:
# [0.936 0.941 0.945 0.948 0.95 ]
